# %%
import numpy as np
import pandas as pd
import re
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def rename_cols(df, master_name):
  rename_dict = {df.columns[i]: master_name[i] for i in range(len(master_name))}
  end_df = df.rename(columns=rename_dict)

   ## validation box
  print("column names before changes:")
  print(df.columns)
  print(" ")
  print("column names after changes:")
  print(end_df.columns)

  return end_df

# %% [markdown]
# # Trimm dataset into managable resource

# %% [markdown]
# The objective of this step is to trim all files into having a common collumns structure. That way data is more managable to process. THe following steps are performed in this process:
#
# - creating a set of required columns for data processing
# - from each scrapped files, trim each files into having only the required columns
# - join all dataset into 1 csv file for title assessment

# %%
##### Dataset columns should be trimmed to the following columns
master_col = ["Author", "Title", "Title_2", "Record_link", "DOI", "Year"]

# RecordID  (index)  : unique identifier for each record, ID is valid only for this database
# Author      : Author of the study. (as written in for citation export)
# Title       : TItle of study
# Title_2     : Second Title of study (if any), applicable if records have a foreign title
# Record_link : Raw link of the records
# DOI         : DIgital Object Identifier for each record
# Year        : Publication year of the study

# %% [markdown]
# # TRID Files
#
#
# ---

# %% [markdown]
# exploration of target columns

# %%
master_col
# Out:
# ['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year']

# %%
TRID_authors = pd.read_csv("/content/TRID-CSV_2024-05-21.csv",
                           #index_col = "RecordID",
                           usecols=["Author1", "Author2", "Author3", "Author4",
                                    "Author5", "Author6", "Author7", "Author8"])

# %%
TRID_authors['All_Authors'] = TRID_authors[TRID_authors.columns].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
TRID_author_complied = TRID_authors["All_Authors"]

# %%
useful_colsTRID = ["Title", "Author_all",]

# %%
TRID_filtered = pd.read_csv("/content/TRID-CSV_2024-05-21.csv",
                            usecols=["Title", "ForeignTitle", "Record URL1", "Record URL2", "Publication date"])

# %%
TRID_filtered.head(3)
# Out:
#                                                Title ForeignTitle  \
# 0  Enhanced Safety of Heavy-Duty Vehicles on High...          NaN
# 1  Restricted Speed Enforcement for Positive Trai...          NaN
# 2  On Speed Management, Public Health, and Risky ...          NaN
#
#                                          Record URL1  \
# 0               https://doi.org/10.4271/2024-01-1964
# 1  https://railroads.dot.gov/sites/fra.dot.gov/fi...
# 2          https://doi.org/10.1177/03611981231182419
#
#                                 Record URL2 Publication date
# 0                                       NaN       2024-04-09
# 1  https://rosap.ntl.bts.gov/view/dot/74200       2024-04-00
# 2                                       NaN       2024-03-00

# %%
TRID_join = pd.concat([TRID_author_complied, TRID_filtered], axis=1)
TRID_join.head(2)
# Out:
#                                          All_Authors  \
# 0  Shiledar, Ankur;Sujan, Vivek;Siekmann, Adam;Yu...
# 1  Liu, Xiang;Holt, Keith;Zhang, Zhipeng;Liu, Xia...
#
#                                                Title ForeignTitle  \
# 0  Enhanced Safety of Heavy-Duty Vehicles on High...          NaN
# 1  Restricted Speed Enforcement for Positive Trai...          NaN
#
#                                          Record URL1  \
# 0               https://doi.org/10.4271/2024-01-1964
# 1  https://railroads.dot.gov/sites/fra.dot.gov/fi...
#
#                                 Record URL2 Publication date
# 0                                       NaN       2024-04-09
# 1  https://rosap.ntl.bts.gov/view/dot/74200       2024-04-00

# %%
TRID_join["Publication date"] = TRID_join["Publication date"].astype(str)
TRID_join["Year"] = TRID_join["Publication date"].apply(lambda text: text.split("-")[0])
TRID_join.head(3)
# Out:
#                                          All_Authors  \
# 0  Shiledar, Ankur;Sujan, Vivek;Siekmann, Adam;Yu...
# 1  Liu, Xiang;Holt, Keith;Zhang, Zhipeng;Liu, Xia...
# 2  Valderrama, Segundo Lopez;Palacios, Manuel San...
#
#                                                Title ForeignTitle  \
# 0  Enhanced Safety of Heavy-Duty Vehicles on High...          NaN
# 1  Restricted Speed Enforcement for Positive Trai...          NaN
# 2  On Speed Management, Public Health, and Risky ...          NaN
#
#                                          Record URL1  \
# 0               https://doi.org/10.4271/2024-01-1964
# 1  https://railroads.dot.gov/sites/fra.dot.gov/fi...
# 2          https://doi.org/10.1177/03611981231182419
#
#                                 Record URL2 Publication date  Year
# 0                                       NaN       2024-04-09  2024
# 1  https://rosap.ntl.bts.gov/view/dot/74200       2024-04-00  2024
# 2                                       NaN       2024-03-00  2024

# %%
TRID_join.drop(columns="Publication date", inplace=True)
TRID_join
# Out:
#                                            All_Authors  \
# 0    Shiledar, Ankur;Sujan, Vivek;Siekmann, Adam;Yu...
# 1    Liu, Xiang;Holt, Keith;Zhang, Zhipeng;Liu, Xia...
# 2    Valderrama, Segundo Lopez;Palacios, Manuel San...
# 3    Thapa, Diwas;Mishra, Sabyasachee;Khattak, Asad...
# 4                                                    ;
# ..                                                 ...
# 490                    HOOK, P;HOOK, P;HOOK, P;HOOK, P
# 491  Smith, G;SENSERRICK, T M;Smith, G;SENSERRICK, ...
# 492  CHAMPNESS, P;FOLKMAN, L;CHAMPNESS, P;FOLKMAN, ...
# 493  Lave, C;Elias, P;Lave, C;Elias, P;Lave, C;Elia...
# 494            KEENAN, D;KEENAN, D;KEENAN, D;KEENAN, D
#
#                                                  Title ForeignTitle  \
# 0    Enhanced Safety of Heavy-Duty Vehicles on High...          NaN
# 1    Restricted Speed Enforcement for Positive Trai...          NaN
# 2    On Speed Management, Public Health, and Risky ...          NaN
# 3    Assessing driver behavior in work zones: A dis...          NaN
# 4    Effectiveness of Automated Speed Enforcement i...          NaN
# ..                                                 ...          ...
# 490                              A PICTURE OF ACCURACY          NaN
# 491  NEW SPEED ENFORCEMENT INITIATIVES: CHANGING AT...          NaN
# 492  THE IMPACT OF SPEED CAMERAS ON SPEED-RELATED C...          NaN
# 493  RESOURCE ALLOCATION IN PUBLIC POLICY: THE EFFE...          NaN
# 494  Speed cameras - measuring the impact on driver...          NaN
#
#                                            Record URL1  \
# 0                 https://doi.org/10.4271/2024-01-1964
# 1    https://railroads.dot.gov/sites/fra.dot.gov/fi...
# 2            https://doi.org/10.1177/03611981231182419
# 3            https://doi.org/10.1016/j.aap.2023.107427
# 4                                                  NaN
# ..                                                 ...
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
# 493                                                NaN
# 494                                                NaN
#
#                                            Record URL2  Year
# 0                                                  NaN  2024
# 1             https://rosap.ntl.bts.gov/view/dot/74200  2024
# 2                                                  NaN  2024
# 3    http://www.sciencedirect.com/science/article/p...  2024
# 4                                                  NaN   nan
# ..                                                 ...   ...
# 490                                                NaN  2003
# 491                                                NaN  2003
# 492                                                NaN  2003
# 493                                                NaN  2003
# 494                                                NaN  2003
#
# [495 rows x 6 columns]

# %%
rename_dict = {TRID_join.columns[i]: master_col[i] for i in range(len(master_col))}
TRID_join.rename(columns=rename_dict, inplace=True)

# %%
TRID_join.head(4)
# Out:
#                                               Author  \
# 0  Shiledar, Ankur;Sujan, Vivek;Siekmann, Adam;Yu...
# 1  Liu, Xiang;Holt, Keith;Zhang, Zhipeng;Liu, Xia...
# 2  Valderrama, Segundo Lopez;Palacios, Manuel San...
# 3  Thapa, Diwas;Mishra, Sabyasachee;Khattak, Asad...
#
#                                                Title Title_2  \
# 0  Enhanced Safety of Heavy-Duty Vehicles on High...     NaN
# 1  Restricted Speed Enforcement for Positive Trai...     NaN
# 2  On Speed Management, Public Health, and Risky ...     NaN
# 3  Assessing driver behavior in work zones: A dis...     NaN
#
#                                          Record_link  \
# 0               https://doi.org/10.4271/2024-01-1964
# 1  https://railroads.dot.gov/sites/fra.dot.gov/fi...
# 2          https://doi.org/10.1177/03611981231182419
# 3          https://doi.org/10.1016/j.aap.2023.107427
#
#                                                  DOI  Year
# 0                                                NaN  2024
# 1           https://rosap.ntl.bts.gov/view/dot/74200  2024
# 2                                                NaN  2024
# 3  http://www.sciencedirect.com/science/article/p...  2024

# %%
TRID_join.to_excel("TRID_cleaned_495.xlsx")

# %% [markdown]
# # Google Scholar files
#
#
# ---

# %% [markdown]
# exploration of target columns

# %%
master_col
# Out:
# ['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year']

# %%
GG_filtered = pd.read_csv("/content/PoP-GGScholarResult.csv",
                          usecols=["Authors", "Title", "Source", "ArticleURL", "FullTextURL", "Year"])

# %%
GG_reorder = GG_filtered[["Authors", "Title", "Source", "ArticleURL", "FullTextURL", "Year"]]
GG_reorder.head(3)
# Out:
#                              Authors  \
# 0   S Shaheen, CJ Rodier, E Cavanagh
# 1  CJ Rodier, SA Shaheen, E Cavanagh
# 2                         AA Siregar
#
#                                                Title  \
# 0  Automated speed enforcement in the US: a revie...
# 1  Automated speed enforcement in the US: a revie...
# 2  How can speed enforcement be made more effecti...
#
#                      Source  \
# 0                       NaN
# 1  … Research Board 87 th …
# 2                       NaN
#
#                                           ArticleURL  \
# 0          https://escholarship.org/uc/item/41k1k365
# 1  https://www.academia.edu/download/75396981/Aut...
# 2             https://etheses.whiterose.ac.uk/20653/
#
#                                          FullTextURL    Year
# 0  https://escholarship.org/content/qt41k1k365/qt...  2007.0
# 1  https://www.academia.edu/download/75396981/Aut...  2007.0
# 2  https://etheses.whiterose.ac.uk/20653/1/Sirega...  2018.0

# %%
rename_GG = {GG_reorder.columns[i]: master_col[i] for i in range(len(master_col))}
GG_reorder.rename(columns=rename_GG, inplace=True)
GG_reorder.head(3)
# Out:
#                               Author  \
# 0   S Shaheen, CJ Rodier, E Cavanagh
# 1  CJ Rodier, SA Shaheen, E Cavanagh
# 2                         AA Siregar
#
#                                                Title  \
# 0  Automated speed enforcement in the US: a revie...
# 1  Automated speed enforcement in the US: a revie...
# 2  How can speed enforcement be made more effecti...
#
#                     Title_2  \
# 0                       NaN
# 1  … Research Board 87 th …
# 2                       NaN
#
#                                          Record_link  \
# 0          https://escholarship.org/uc/item/41k1k365
# 1  https://www.academia.edu/download/75396981/Aut...
# 2             https://etheses.whiterose.ac.uk/20653/
#
#                                                  DOI    Year
# 0  https://escholarship.org/content/qt41k1k365/qt...  2007.0
# 1  https://www.academia.edu/download/75396981/Aut...  2007.0
# 2  https://etheses.whiterose.ac.uk/20653/1/Sirega...  2018.0

# %%
GG_reorder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Author       359 non-null    object
#  1   Title        359 non-null    object
#  2   Title_2      264 non-null    object
#  3   Record_link  359 non-null    object
#  4   DOI          255 non-null    object
#  5   Year         344 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 17.0+ KB

# %%
GG_reorder["Year"]  = GG_reorder["Year"].astype(str).str[:4]
GG_reorder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Author       359 non-null    object
#  1   Title        359 non-null    object
#  2   Title_2      264 non-null    object
#  3   Record_link  359 non-null    object
#  4   DOI          255 non-null    object
#  5   Year         359 non-null    object
# dtypes: object(6)
# memory usage: 17.0+ KB

# %%
GG_reorder
# Out:
#                                 Author  \
# 0     S Shaheen, CJ Rodier, E Cavanagh
# 1    CJ Rodier, SA Shaheen, E Cavanagh
# 2                           AA Siregar
# 3                         Z Abouchacra
# 4                      SA Al Ramadhani
# ..                                 ...
# 354                   I TAUFIQURRAHMAN
# 355                    N Dharma Kusuma
# 356                            P Marks
# 357                        A Gasruddin
# 358                                조준호
#
#                                                  Title  \
# 0    Automated speed enforcement in the US: a revie...
# 1    Automated speed enforcement in the US: a revie...
# 2    How can speed enforcement be made more effecti...
# 3    Automated Speed Enforcement as a Mechanism of ...
# 4    A gap analysis of the automated speed enforcem...
# ..                                                 ...
# 354   Design dan Implementasi Speed Gun Berbasis Radar
# 355  IMPLEMENTASI TILANG ATAS PELANGGARAN BATAS KEC...
# 356                             Speed gun with a twist
# 357  Studi Kecepatan Kendaraan Menggunakan Alat Apl...
# 358  경험적 베이즈 방법을 이용한 고속도로 구간과속단속시스템 운영효과 분석: An Ana...
#
#                                  Title_2  \
# 0                                    NaN
# 1               … Research Board 87 th …
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 354                                  NaN
# 355                                  NaN
# 356                        New scientist
# 357  Jurnal MEDIA INOVASI Teknik Sipil …
# 358                                  NaN
#
#                                            Record_link  \
# 0            https://escholarship.org/uc/item/41k1k365
# 1    https://www.academia.edu/download/75396981/Aut...
# 2               https://etheses.whiterose.ac.uk/20653/
# 3           https://ruor.uottawa.ca/handle/10393/45429
# 4                    https://eprints.qut.edu.au/134252
# ..                                                 ...
# 354  https://repository.telkomuniversity.ac.id/pust...
# 355     http://repository.upnjatim.ac.id/id/eprint/742
# 356  https://dialnet.unirioja.es/servlet/articulo?c...
# 357  https://www.ejournal.lppmunidayan.ac.id/index....
# 358  https://www.dbpia.co.kr/journal/detail?nodeId=...
#
#                                                    DOI  Year
# 0    https://escholarship.org/content/qt41k1k365/qt...  2007
# 1    https://www.academia.edu/download/75396981/Aut...  2007
# 2    https://etheses.whiterose.ac.uk/20653/1/Sirega...  2018
# 3    https://ruor.uottawa.ca/bitstream/10393/45429/...  2023
# 4    https://eprints.qut.edu.au/134252/1/Saif_Al%20...  2019
# ..                                                 ...   ...
# 354                                                NaN  2019
# 355   http://repository.upnjatim.ac.id/742/1/Cover.pdf  2020
# 356                                                NaN  2013
# 357  https://www.ejournal.lppmunidayan.ac.id/index....  2017
# 358                                                NaN  2016
#
# [359 rows x 6 columns]

# %%
GG_reorder.to_excel("GGScholar_cleaned_359.xlsx")

# %% [markdown]
# # Scopus Data
#
#
# ---

# %%
scopus_df = pd.read_csv("/content/scopus_Paper.csv")
scopus_df.head(3)
# Out:
#                                    Authors  \
# 0  Agina S.; Momeni Rad F.; El-Basyouny K.
# 1          Ammar K.; Al-Emami A.; Baher A.
# 2             Carus L.; Mamaqi-Kapllani X.
#
#                                    Author full names  \
# 0  Agina, Samaa (57355267500); Momeni Rad, Faeze ...
# 1  Ammar, Khalid (57213686839); Al-Emami, Abdulla...
# 2  Carus, Luis (35112742100); Mamaqi-Kapllani, Xh...
#
#                             Author(s) ID  \
# 0  57355267500; 58772868300; 14832701400
# 1  57213686839; 57245283200; 57245189000
# 2               35112742100; 58180739900
#
#                                                Title  Year  \
# 0  Linking Deployment Outcomes to Program Impacts...  2023
# 1         Real-time Vehicle Speed Enforcement System  2021
# 2  Managing Accident Prevention in Ski Resorts: P...  2023
#
#                                         Source title  \
# 0                                             Safety
# 1  2021 10th Mediterranean Conference on Embedded...
# 2  International Journal of Environmental Researc...
#
#                               DOI  \
# 0           10.3390/safety9040088
# 1  10.1109/MECO52532.2021.9460297
# 2          10.3390/ijerph20075302
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                             Abstract
# 0  Previous research has delved into the effectiv...
# 1  Traffic injuries and deaths are important road...
# 2  Velocity is one of the main factors affecting ...

# %%
scopus_df.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'DOI', 'Link', 'Abstract'],
#       dtype='object')

# %%
master_col
# Out:
# ['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year']

# %%
scopus_select = pd.read_csv("/content/scopus_Paper.csv", usecols=[
    "Authors", "Title", "Source title", "Link", "DOI", "Year"
])

# %%
scopus_select.head(4)
# Out:
#                                             Authors  \
# 0           Agina S.; Momeni Rad F.; El-Basyouny K.
# 1                   Ammar K.; Al-Emami A.; Baher A.
# 2                      Carus L.; Mamaqi-Kapllani X.
# 3  Braden A.W.; Parker I.D.; Lopez R.R.; Silvy N.J.
#
#                                                Title  Year  \
# 0  Linking Deployment Outcomes to Program Impacts...  2023
# 1         Real-time Vehicle Speed Enforcement System  2021
# 2  Managing Accident Prevention in Ski Resorts: P...  2023
# 3  Temporal Movement Patterns Predict Collisions ...  2020
#
#                                         Source title  \
# 0                                             Safety
# 1  2021 10th Mediterranean Conference on Embedded...
# 2  International Journal of Environmental Researc...
# 3                            Southeastern Naturalist
#
#                               DOI  \
# 0           10.3390/safety9040088
# 1  10.1109/MECO52532.2021.9460297
# 2          10.3390/ijerph20075302
# 3            10.1656/058.019.0409
#
#                                                 Link
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...

# %%
scopus_reorder = scopus_select[["Authors", "Title", "Source title", "Link", "DOI", "Year"]]
scopus_reorder.head(3)
# Out:
#                                    Authors  \
# 0  Agina S.; Momeni Rad F.; El-Basyouny K.
# 1          Ammar K.; Al-Emami A.; Baher A.
# 2             Carus L.; Mamaqi-Kapllani X.
#
#                                                Title  \
# 0  Linking Deployment Outcomes to Program Impacts...
# 1         Real-time Vehicle Speed Enforcement System
# 2  Managing Accident Prevention in Ski Resorts: P...
#
#                                         Source title  \
# 0                                             Safety
# 1  2021 10th Mediterranean Conference on Embedded...
# 2  International Journal of Environmental Researc...
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
#
#                               DOI  Year
# 0           10.3390/safety9040088  2023
# 1  10.1109/MECO52532.2021.9460297  2021
# 2          10.3390/ijerph20075302  2023

# %%
rename_scopus_dict = {scopus_reorder.columns[i] : master_col[i] for i in range(len(master_col))}
scopus_reorder.rename(columns=rename_scopus_dict, inplace=True)
scopus_reorder.head(3)
# Out:
#                                     Author  \
# 0  Agina S.; Momeni Rad F.; El-Basyouny K.
# 1          Ammar K.; Al-Emami A.; Baher A.
# 2             Carus L.; Mamaqi-Kapllani X.
#
#                                                Title  \
# 0  Linking Deployment Outcomes to Program Impacts...
# 1         Real-time Vehicle Speed Enforcement System
# 2  Managing Accident Prevention in Ski Resorts: P...
#
#                                              Title_2  \
# 0                                             Safety
# 1  2021 10th Mediterranean Conference on Embedded...
# 2  International Journal of Environmental Researc...
#
#                                          Record_link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
#
#                               DOI  Year
# 0           10.3390/safety9040088  2023
# 1  10.1109/MECO52532.2021.9460297  2021
# 2          10.3390/ijerph20075302  2023

# %%
scopus_reorder.shape
# Out:
# (420, 6)

# %%
scopus_reorder.to_excel("scopus_cleaned_420.xlsx")

# %% [markdown]
# # PubMed Dataset

# %%
PubMed_raw = pd.read_csv("/content/csv-SpeedEnfor-set.csv")
PubMed_raw.head(2)
# Out:
#        PMID                                              Title  \
# 0  31656123                      Speed in a high-speed society
# 1  23474237  Effects of average speed enforcement on speed ...
#
#                             Authors  \
# 0                          Hydén C.
# 1  Soole DW, Watson BC, Fleiter JJ.
#
#                                             Citation First Author  \
# 0  Int J Inj Contr Saf Promot. 2020 Mar;27(1):44-...      Hydén C
# 1  Accid Anal Prev. 2013 May;54:46-56. doi: 10.10...     Soole DW
#
#                  Journal/Book  Publication Year Create Date PMCID NIHMS ID  \
# 0  Int J Inj Contr Saf Promot              2020  2019/10/29   NaN      NaN
# 1             Accid Anal Prev              2013  2013/03/12   NaN      NaN
#
#                              DOI
# 0  10.1080/17457300.2019.1680566
# 1      10.1016/j.aap.2013.01.018

# %%
master_col
# Out:
# ['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year']

# %%
Pubmed_selected = PubMed_raw[["Authors", "Title", "Journal/Book", "Citation", "DOI", "Publication Year"]]
Pubmed_selected.head(2)
# Out:
#                             Authors  \
# 0                          Hydén C.
# 1  Soole DW, Watson BC, Fleiter JJ.
#
#                                                Title  \
# 0                      Speed in a high-speed society
# 1  Effects of average speed enforcement on speed ...
#
#                  Journal/Book  \
# 0  Int J Inj Contr Saf Promot
# 1             Accid Anal Prev
#
#                                             Citation  \
# 0  Int J Inj Contr Saf Promot. 2020 Mar;27(1):44-...
# 1  Accid Anal Prev. 2013 May;54:46-56. doi: 10.10...
#
#                              DOI  Publication Year
# 0  10.1080/17457300.2019.1680566              2020
# 1      10.1016/j.aap.2013.01.018              2013

# %%
pubmed_reorder = Pubmed_selected[["Authors", "Title", "Journal/Book", "PMCID", "DOI", "Publication Year"]]
pubmed_reorder.head(2)
# Out:
#                             Authors  \
# 0                          Hydén C.
# 1  Soole DW, Watson BC, Fleiter JJ.
#
#                                                Title  \
# 0                      Speed in a high-speed society
# 1  Effects of average speed enforcement on speed ...
#
#                  Journal/Book PMCID                            DOI  \
# 0  Int J Inj Contr Saf Promot   NaN  10.1080/17457300.2019.1680566
# 1             Accid Anal Prev   NaN      10.1016/j.aap.2013.01.018
#
#    Publication Year
# 0              2020
# 1              2013

# %%
def rename_cols(df, master_name):
  rename_dict = {df.columns[i]: master_name[i] for i in range(len(master_name))}
  end_df = df.rename(columns=rename_dict)

   ## validation box
  print("column names before changes:")
  print(df.columns)
  print(" ")
  print("column names after changes:")
  print(end_df.columns)

  return end_df

pubmed_rename = rename_cols(Pubmed_selected, master_col)
# Out:
# column names before changes:
# Index(['Authors', 'Title', 'Journal/Book', 'Citation', 'DOI',
#        'Publication Year'],
#       dtype='object')
#
# column names after changes:
# Index(['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year'], dtype='object')

# %%
pubmed_rename.head(3)
# Out:
#                                  Author  \
# 0                              Hydén C.
# 1      Soole DW, Watson BC, Fleiter JJ.
# 2  Zhai Z, Xu J, Song G, Hatzopoulou M.
#
#                                                Title  \
# 0                      Speed in a high-speed society
# 1  Effects of average speed enforcement on speed ...
# 2  Comparative analysis of drive-cycles, speed li...
#
#                       Title_2  \
# 0  Int J Inj Contr Saf Promot
# 1             Accid Anal Prev
# 2           Sci Total Environ
#
#                                          Record_link  \
# 0  Int J Inj Contr Saf Promot. 2020 Mar;27(1):44-...
# 1  Accid Anal Prev. 2013 May;54:46-56. doi: 10.10...
# 2  Sci Total Environ. 2022 Mar 10;811:152323. doi...
#
#                                DOI  Year
# 0    10.1080/17457300.2019.1680566  2020
# 1        10.1016/j.aap.2013.01.018  2013
# 2  10.1016/j.scitotenv.2021.152323  2022

# %%
pubmed_rename.to_excel("Pubmed_cleaned_74.xlsx")

# %% [markdown]
# # IEEE General

# %%
ie3x_raw = pd.read_csv("/content/export2024.05.21-16.32.43.csv")
ie3x_raw.head(3)
# Out:
#                                       Document Title  \
# 0  A traffic speed enforcement system for high sp...
# 1  Scheduling resources in a mobile photo enforce...
# 2  Vehicle Speed Enforcement Using Absolute Speed...
#
#                                              Authors  \
# 0  Kuan-Lin Chiu; C. -C. Lin; S. D. Gupta; Ching-...
# 1                      Y. Li; A. Kim; K. El-Basyouny
# 2       M. Mandava; R. S. Gammenthaler; S. F. Hocker
#
#                                  Author Affiliations  \
# 0  ICT Design & Validation for Vehicle Dep., Indu...
# 1  Department of Civil and Environmental Engineer...
# 2  Applied Concepts, Inc., Richardson, TX, USA; A...
#
#                                    Publication Title Date Added To Xplore  \
# 0  16th International IEEE Conference on Intellig...          30 Jan 2014
# 1  2017 4th International Conference on Transport...          21 Sep 2017
# 2  2018 IEEE 88th Vehicular Technology Conference...          14 Apr 2019
#
#    Publication Year Volume  Issue  Start Page  End Page  ... Mesh_Terms  \
# 0              2013    NaN    NaN        1292      1297  ...        NaN
# 1              2017    NaN    NaN         645       652  ...        NaN
# 2              2018    NaN    NaN           1         5  ...        NaN
#
#   Article Citation Count Patent Citation Count Reference Count License  \
# 0                    NaN                   NaN            15.0    IEEE
# 1                    1.0                   NaN            13.0    IEEE
# 2                    3.0                   NaN            14.0    IEEE
#
#    Online Date Issue Date Meeting Date  Publisher  Document Identifier
# 0  30 Jan 2014        NaN          NaN       IEEE     IEEE Conferences
# 1  21 Sep 2017        NaN          NaN       IEEE     IEEE Conferences
# 2  14 Apr 2019        NaN          NaN       IEEE     IEEE Conferences
#
# [3 rows x 28 columns]

# %%
ie3x_raw.columns
# Out:
# Index(['Document Title', 'Authors', 'Author Affiliations', 'Publication Title',
#        'Date Added To Xplore', 'Publication Year', 'Volume', 'Issue',
#        'Start Page', 'End Page', 'Abstract', 'ISSN', 'ISBNs', 'DOI',
#        'Funding Information', 'PDF Link', 'Author Keywords', 'IEEE Terms',
#        'Mesh_Terms', 'Article Citation Count', 'Patent Citation Count',
#        'Reference Count', 'License', 'Online Date', 'Issue Date',
#        'Meeting Date', 'Publisher', 'Document Identifier'],
#       dtype='object')

# %%
master_col
# Out:
# ['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year']

# %%
ie3_filtered = ie3x_raw[["Authors", "Document Title", "Author Keywords", "PDF Link",
                        "DOI", "Publication Year"]]
ie3_filtered.head(2)
# Out:
#                                              Authors  \
# 0  Kuan-Lin Chiu; C. -C. Lin; S. D. Gupta; Ching-...
# 1                      Y. Li; A. Kim; K. El-Basyouny
#
#                                       Document Title  \
# 0  A traffic speed enforcement system for high sp...
# 1  Scheduling resources in a mobile photo enforce...
#
#                                      Author Keywords  \
# 0   DSRC;IEEE 802.11p;Speed Enforcement;Speed Camera
# 1  resource scheduling;mobile photo enforcement;i...
#
#                                             PDF Link  \
# 0  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 1  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
#
#                           DOI  Publication Year
# 0   10.1109/ITSC.2013.6728409              2013
# 1  10.1109/ICTIS.2017.8047835              2017

# %%
ie3_rename = rename_cols(ie3_filtered, master_col)
ie3_rename.head(2)
# Out:
# column names before changes:
# Index(['Authors', 'Document Title', 'Author Keywords', 'PDF Link', 'DOI',
#        'Publication Year'],
#       dtype='object')
#
# column names after changes:
# Index(['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year'], dtype='object')
#                                               Author  \
# 0  Kuan-Lin Chiu; C. -C. Lin; S. D. Gupta; Ching-...
# 1                      Y. Li; A. Kim; K. El-Basyouny
#
#                                                Title  \
# 0  A traffic speed enforcement system for high sp...
# 1  Scheduling resources in a mobile photo enforce...
#
#                                              Title_2  \
# 0   DSRC;IEEE 802.11p;Speed Enforcement;Speed Camera
# 1  resource scheduling;mobile photo enforcement;i...
#
#                                          Record_link  \
# 0  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 1  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
#
#                           DOI  Year
# 0   10.1109/ITSC.2013.6728409  2013
# 1  10.1109/ICTIS.2017.8047835  2017

# %%
ie3_rename.shape
# Out:
# (47, 6)

# %%
ie3_rename.to_excel("ie3_cleaned_47.xlsx")

# %% [markdown]
# # Springer dataset

# %%
springer_data = pd.read_csv("/content/SearchResults (1).csv")
springer_data.head(2)
# Out:
#                                           Item Title  \
# 0  Robust Vehicle Speed Estimation Based on Visio...
# 1  Impact of the decision-making environment on p...
#
#                         Publication Title  Book Series Title  Journal Volume  \
# 0  Intelligent Computing and Optimization                NaN             NaN
# 1       Canadian Journal of Public Health                NaN           108.0
#
#   Journal Issue                     Item DOI  \
# 0           NaN  10.1007/978-3-031-36246-0_4
# 1         5 - 6       10.17269/CJPH.108.6231
#
#                                 Authors  Publication Year  \
# 0  Dea Angelia KamilWahyonoAgus Harjoko              2023
# 1                  Curt J. Pankratz PhD              2017
#
#                                                  URL Content Type
# 0  http://link.springer.com/chapter/10.1007/978-3...      Chapter
# 1  http://link.springer.com/article/10.17269/CJPH...      Article

# %%
springer_data.columns
# Out:
# Index(['Item Title', 'Publication Title', 'Book Series Title',
#        'Journal Volume', 'Journal Issue', 'Item DOI', 'Authors',
#        'Publication Year', 'URL', 'Content Type'],
#       dtype='object')

# %%
springer_filtered = springer_data[["Authors","Item Title", "Publication Title",
                                   "URL", "Item DOI", "Publication Year"]]
springer_filtered.head(2)
# Out:
#                                 Authors  \
# 0  Dea Angelia KamilWahyonoAgus Harjoko
# 1                  Curt J. Pankratz PhD
#
#                                           Item Title  \
# 0  Robust Vehicle Speed Estimation Based on Visio...
# 1  Impact of the decision-making environment on p...
#
#                         Publication Title  \
# 0  Intelligent Computing and Optimization
# 1       Canadian Journal of Public Health
#
#                                                  URL  \
# 0  http://link.springer.com/chapter/10.1007/978-3...
# 1  http://link.springer.com/article/10.17269/CJPH...
#
#                       Item DOI  Publication Year
# 0  10.1007/978-3-031-36246-0_4              2023
# 1       10.17269/CJPH.108.6231              2017

# %%
master_col
# Out:
# ['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year']

# %%
springer_rename = rename_cols(springer_filtered, master_col)
# Out:
# column names before changes:
# Index(['Authors', 'Item Title', 'Publication Title', 'URL', 'Item DOI',
#        'Publication Year'],
#       dtype='object')
#
# column names after changes:
# Index(['Author', 'Title', 'Title_2', 'Record_link', 'DOI', 'Year'], dtype='object')

# %%
springer_rename.shape
# Out:
# (172, 6)

# %%
springer_rename.to_excel("springer_cleaned_172.xlsx")

# %% [markdown]
# # Merging documents into one databases

# %%
trid_df = pd.read_excel("/content/TRID_cleaned_495.xlsx")
gg_df = pd.read_excel("/content/GGScholar_cleaned_359.xlsx")
scopus_df = pd.read_excel("/content/scopus_cleaned_420.xlsx")
pubmed_df = pd.read_excel("/content/Pubmed_cleaned_74.xlsx")
ie3_df = pd.read_excel("/content/ie3_cleaned_47.xlsx")
springer_df = pd.read_excel("/content/springer_cleaned_172.xlsx")

# %%
final_df = pd.concat([scopus_df, gg_df, pubmed_df, trid_df, springer_df, ie3_df], axis=0, ignore_index=True)
final_df.head(3)
# Out:
#    Unnamed: 0                                   Author  \
# 0           0  Agina S.; Momeni Rad F.; El-Basyouny K.
# 1           1          Ammar K.; Al-Emami A.; Baher A.
# 2           2             Carus L.; Mamaqi-Kapllani X.
#
#                                                Title  \
# 0  Linking Deployment Outcomes to Program Impacts...
# 1         Real-time Vehicle Speed Enforcement System
# 2  Managing Accident Prevention in Ski Resorts: P...
#
#                                              Title_2  \
# 0                                             Safety
# 1  2021 10th Mediterranean Conference on Embedded...
# 2  International Journal of Environmental Researc...
#
#                                          Record_link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
#
#                               DOI    Year
# 0           10.3390/safety9040088  2023.0
# 1  10.1109/MECO52532.2021.9460297  2021.0
# 2          10.3390/ijerph20075302  2023.0

# %%
final_df.columns[0]
# Out:
# 'Unnamed: 0'

# %%
rename_index = {"Unnamed: 0": "index"}
final_df.rename(columns=rename_index, inplace=True)
final_df.set_index("index", inplace=True)
final_df.head(3)
# Out:
#                                         Author  \
# index
# 0      Agina S.; Momeni Rad F.; El-Basyouny K.
# 1              Ammar K.; Al-Emami A.; Baher A.
# 2                 Carus L.; Mamaqi-Kapllani X.
#
#                                                    Title  \
# index
# 0      Linking Deployment Outcomes to Program Impacts...
# 1             Real-time Vehicle Speed Enforcement System
# 2      Managing Accident Prevention in Ski Resorts: P...
#
#                                                  Title_2  \
# index
# 0                                                 Safety
# 1      2021 10th Mediterranean Conference on Embedded...
# 2      International Journal of Environmental Researc...
#
#                                              Record_link  \
# index
# 0      https://www.scopus.com/inward/record.uri?eid=2...
# 1      https://www.scopus.com/inward/record.uri?eid=2...
# 2      https://www.scopus.com/inward/record.uri?eid=2...
#
#                                   DOI    Year
# index
# 0               10.3390/safety9040088  2023.0
# 1      10.1109/MECO52532.2021.9460297  2021.0
# 2              10.3390/ijerph20075302  2023.0

# %%
final_df.shape
# Out:
# (1567, 6)

# %%
final_df.to_excel("title_screening_final_df_1567.xlsx")
